# %%
using Plots
gadfly(leg=false, size=(500,300))

n = 10
y = rand(n)
vx, vy = randn(n), randn(n)

quiver(y, quiver=(vx,vy))
# Out:
# Compose.SVG(132.2751322751323mm,79.36507936507938mm,IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=3706, maxsize=Inf, ptr=3707, mark=-1),nothing,"img-9b4190a1",0,Compose.SVGPropertyFrame[],Dict{Type{T},Union{Compose.Property{P<:Compose.PropertyPrimitive},Void}}(),Dict{Compose.ClipPrimitive{P<:NTuple{N,Measures.Measure}},ASCIIString}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}([(5.506666666666675mm,1.0mm),(131.2751322751323mm,1.0mm),(131.2751322751323mm,73.73174603174606mm),(5.506666666666675mm,73.73174603174606mm)])=>"img-9b4190a1-4"),Tuple{Compose.FormPrimitive,ASCIIString}[],Set{AbstractString}(),true,false,nothing,true,"img-9b4190a1-12",false,12,AbstractString["/home/tom/.julia/v0.4/Gadfly/src/gadfly.js"],Tuple{AbstractString,AbstractString}[("Snap.svg","Snap"),("Gadfly","Gadfly")],AbstractString["fig.select(\"#img-9b4190a1-5\")\n   .init_gadfly();"],false,:none)

# %%
e(x,y) = exp(-x^2-y^2)
f(x,y) = x * e(x,y)
x = -2:0.2:2
contour(x,x,f, xlim=(-2,2), ylim=(-2,2))
# Out:
# Compose.SVG(132.2751322751323mm,79.36507936507938mm,IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=9155, maxsize=Inf, ptr=9156, mark=-1),nothing,"img-5041fd44",0,Compose.SVGPropertyFrame[],Dict{Type{T},Union{Compose.Property{P<:Compose.PropertyPrimitive},Void}}(Compose.Property{Compose.SVGClassPrimitive}=>nothing,Compose.Property{Compose.StrokePrimitive}=>nothing),Dict{Compose.ClipPrimitive{P<:NTuple{N,Measures.Measure}},ASCIIString}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}([(5.506666666666661mm,1.0mm),(131.2751322751323mm,1.0mm),(131.2751322751323mm,73.73174603174606mm),(5.506666666666661mm,73.73174603174606mm)])=>"img-5041fd44-4"),Tuple{Compose.FormPrimitive,ASCIIString}[],Set{AbstractString}(),true,false,nothing,true,"img-5041fd44-11",false,11,AbstractString["/home/tom/.julia/v0.4/Gadfly/src/gadfly.js"],Tuple{AbstractString,AbstractString}[("Snap.svg","Snap"),("Gadfly","Gadfly")],AbstractString["fig.select(\"#img-5041fd44-5\")\n   .init_gadfly();"],false,:none)

# %%
# take the derivative, then scale down
df(x,y) = P2(e(x,y) + x * e(x,y) * (-2x), x * e(x,y) * (-2y)) / 4

# get a grid of points as a vector
pts = vec(P2[(x[i],x[j]) for i=1:length(x), j=1:length(x)])

# add the quiver plot
quiver!(pts, quiver=df, marker=(:none,stroke(2)))
# Out:
# Compose.SVG(132.2751322751323mm,79.36507936507938mm,IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=46683, maxsize=Inf, ptr=46684, mark=-1),nothing,"img-422078af",0,Compose.SVGPropertyFrame[],Dict{Type{T},Union{Compose.Property{P<:Compose.PropertyPrimitive},Void}}(Compose.Property{Compose.SVGClassPrimitive}=>nothing,Compose.Property{Compose.StrokePrimitive}=>nothing),Dict{Compose.ClipPrimitive{P<:NTuple{N,Measures.Measure}},ASCIIString}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}([(5.506666666666661mm,1.0mm),(131.2751322751323mm,1.0mm),(131.2751322751323mm,73.73174603174606mm),(5.506666666666661mm,73.73174603174606mm)])=>"img-422078af-4"),Tuple{Compose.FormPrimitive,ASCIIString}[],Set{AbstractString}(),true,false,nothing,true,"img-422078af-13",false,13,AbstractString["/home/tom/.julia/v0.4/Gadfly/src/gadfly.js"],Tuple{AbstractString,AbstractString}[("Snap.svg","Snap"),("Gadfly","Gadfly")],AbstractString["fig.select(\"#img-422078af-5\")\n   .init_gadfly();"],false,:none)
