# %%
using Plots
C(g::ColorGradient) = RGB[g[z] for z=linspace(0,1,30)]
g = :inferno
# Out:
# :inferno

# %%
cgrad(g) |> C
# Out:
# 30-element Array{ColorTypes.RGB{T<:Union{AbstractFloat,FixedPointNumbers.FixedPoint{T<:Integer,f}}},1}:
#  RGB{Float64}(0.001462,0.000466,0.013866)
#  RGB{Float64}(0.016561,0.013136,0.080282)
#  RGB{Float64}(0.051644,0.032474,0.159254)
#  RGB{Float64}(0.09299,0.045583,0.234358)
#  RGB{Float64}(0.149073,0.045468,0.317085)
#  RGB{Float64}(0.211095,0.03703,0.378563)
#  RGB{Float64}(0.271347,0.040922,0.411976)
#  RGB{Float64}(0.328921,0.057827,0.427511)
#  RGB{Float64}(0.379001,0.076253,0.432719)
#  RGB{Float64}(0.434987,0.097069,0.432039)
#  RGB{Float64}(0.491022,0.117179,0.425552)
#  RGB{Float64}(0.547157,0.136929,0.413511)
#  RGB{Float64}(0.603139,0.157151,0.395891)
#  ⋮
#  RGB{Float64}(0.886302,0.342586,0.202968)
#  RGB{Float64}(0.919879,0.393389,0.16007)
#  RGB{Float64}(0.946965,0.449191,0.115272)
#  RGB{Float64}(0.967322,0.509078,0.068659)
#  RGB{Float64}(0.979666,0.565057,0.031409)
#  RGB{Float64}(0.986964,0.630485,0.030908)
#  RGB{Float64}(0.987124,0.697944,0.087731)
# ...

# %%
cgrad(g, scale=:log) |> C
# Out:
# 30-element Array{ColorTypes.RGB{T<:Union{AbstractFloat,FixedPointNumbers.FixedPoint{T<:Integer,f}}},1}:
#  RGB{Float64}(0.001462,0.000466,0.013866)
#  RGB{Float64}(0.00589743,0.00418789,0.0333761)
#  RGB{Float64}(0.0103329,0.00790978,0.0528862)
#  RGB{Float64}(0.0147683,0.0116317,0.0723964)
#  RGB{Float64}(0.0243691,0.0174399,0.097858)
#  RGB{Float64}(0.0374738,0.0246633,0.127357)
#  RGB{Float64}(0.0505786,0.0318868,0.156856)
#  RGB{Float64}(0.068858,0.0379318,0.190523)
#  RGB{Float64}(0.0875953,0.0438726,0.224559)
#  RGB{Float64}(0.114266,0.0455394,0.265742)
#  RGB{Float64}(0.144145,0.0454781,0.309815)
#  RGB{Float64}(0.180784,0.0411537,0.348518)
#  RGB{Float64}(0.219507,0.0375734,0.383228)
#  ⋮
#  RGB{Float64}(0.504391,0.121883,0.422684)
#  RGB{Float64}(0.566811,0.144028,0.407325)
#  RGB{Float64}(0.630456,0.167844,0.384624)
#  RGB{Float64}(0.698591,0.197177,0.35184)
#  RGB{Float64}(0.771372,0.238038,0.305587)
#  RGB{Float64}(0.838487,0.290325,0.25133)
# ...

# %%
cgrad(g, scale=:exp) |> C
# Out:
# 30-element Array{ColorTypes.RGB{T<:Union{AbstractFloat,FixedPointNumbers.FixedPoint{T<:Integer,f}}},1}:
#  RGB{Float64}(0.001462,0.000466,0.013866)
#  RGB{Float64}(0.115123,0.0455376,0.267006)
#  RGB{Float64}(0.275859,0.0422467,0.413193)
#  RGB{Float64}(0.394667,0.0820777,0.432529)
#  RGB{Float64}(0.499977,0.12033,0.423631)
#  RGB{Float64}(0.59148,0.152939,0.399561)
#  RGB{Float64}(0.665169,0.182169,0.36901)
#  RGB{Float64}(0.734041,0.215776,0.330532)
#  RGB{Float64}(0.792857,0.252871,0.28953)
#  RGB{Float64}(0.838159,0.290036,0.251619)
#  RGB{Float64}(0.877373,0.332432,0.212247)
#  RGB{Float64}(0.909509,0.377699,0.173319)
#  RGB{Float64}(0.934655,0.423831,0.135631)
#  ⋮
#  RGB{Float64}(0.987081,0.679915,0.0725449)
#  RGB{Float64}(0.984913,0.71942,0.11224)
#  RGB{Float64}(0.980952,0.757902,0.156156)
#  RGB{Float64}(0.974569,0.794312,0.204059)
#  RGB{Float64}(0.967455,0.830094,0.253167)
#  RGB{Float64}(0.960432,0.859927,0.302689)
#  RGB{Float64}(0.953428,0.888537,0.352296)
# ...

# %%
cgrad(g, [0.99]) |> C
# Out:
# 30-element Array{ColorTypes.RGB{T<:Union{AbstractFloat,FixedPointNumbers.FixedPoint{T<:Integer,f}}},1}:
#  RGB{Float64}(0.001462,0.000466,0.013866)
#  RGB{Float64}(0.0160577,0.0127137,0.0780681)
#  RGB{Float64}(0.0493051,0.0311848,0.153989)
#  RGB{Float64}(0.0888554,0.0442721,0.226848)
#  RGB{Float64}(0.141595,0.0454833,0.306055)
#  RGB{Float64}(0.200758,0.0384363,0.368317)
#  RGB{Float64}(0.259297,0.0401436,0.405293)
#  RGB{Float64}(0.315487,0.0538825,0.423886)
#  RGB{Float64}(0.365646,0.0713394,0.43133)
#  RGB{Float64}(0.418191,0.0908242,0.432243)
#  RGB{Float64}(0.472344,0.110476,0.427714)
#  RGB{Float64}(0.526574,0.129687,0.417926)
#  RGB{Float64}(0.580746,0.149062,0.402939)
#  ⋮
#  RGB{Float64}(0.862546,0.31557,0.227655)
#  RGB{Float64}(0.898614,0.361214,0.187239)
#  RGB{Float64}(0.928908,0.41199,0.145137)
#  RGB{Float64}(0.953072,0.467157,0.101288)
#  RGB{Float64}(0.970614,0.524006,0.0587257)
#  RGB{Float64}(0.981369,0.580324,0.0312921)
# ...

# %%
cgrad(g, [0.01, 0.99]) |> C
# Out:
# 30-element Array{ColorTypes.RGB{T<:Union{AbstractFloat,FixedPointNumbers.FixedPoint{T<:Integer,f}}},1}:
#  RGB{Float64}(0.001462,0.000466,0.013866)
#  RGB{Float64}(0.0471172,0.0299788,0.149064)
#  RGB{Float64}(0.0849875,0.0430458,0.219822)
#  RGB{Float64}(0.1346,0.0454977,0.295736)
#  RGB{Float64}(0.191088,0.0397519,0.358731)
#  RGB{Float64}(0.248024,0.0394154,0.399042)
#  RGB{Float64}(0.30292,0.0501925,0.420495)
#  RGB{Float64}(0.353153,0.0667428,0.430031)
#  RGB{Float64}(0.402479,0.0849823,0.432434)
#  RGB{Float64}(0.45487,0.104205,0.429737)
#  RGB{Float64}(0.507319,0.122913,0.422056)
#  RGB{Float64}(0.559798,0.141495,0.409532)
#  RGB{Float64}(0.611079,0.160259,0.392616)
#  ⋮
#  RGB{Float64}(0.877362,0.332419,0.212259)
#  RGB{Float64}(0.910131,0.37864,0.172524)
#  RGB{Float64}(0.937354,0.42939,0.131168)
#  RGB{Float64}(0.958785,0.483964,0.0882064)
#  RGB{Float64}(0.973693,0.53797,0.0494332)
#  RGB{Float64}(0.982962,0.594605,0.0311827)
#  RGB{Float64}(0.987026,0.656598,0.052904)
# ...
