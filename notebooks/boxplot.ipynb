# %%
using Plots
gadfly(leg=false, size=(500,300))

# load a dataset
using RDatasets
singers = dataset("lattice", "singer")

boxplot(singers, :VoicePart, :Height,
        marker=(0.3, :orange, stroke(3)))
# Out:
# Compose.SVG(132.2751322751323mm,79.36507936507938mm,IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=5312, maxsize=Inf, ptr=5313, mark=-1),nothing,"img-82be9b28",0,Compose.SVGPropertyFrame[],Dict{Type{T},Union{Compose.Property{P<:Compose.PropertyPrimitive},Void}}(),Dict{Compose.ClipPrimitive{P<:NTuple{N,Measures.Measure}},ASCIIString}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}([(6.13333333333334mm,1.0mm),(131.2751322751323mm,1.0mm),(131.2751322751323mm,73.73174603174606mm),(6.13333333333334mm,73.73174603174606mm)])=>"img-82be9b28-4"),Tuple{Compose.FormPrimitive,ASCIIString}[],Set{AbstractString}(),true,false,nothing,true,"img-82be9b28-11",false,11,AbstractString["/home/tom/.julia/v0.4/Gadfly/src/gadfly.js"],Tuple{AbstractString,AbstractString}[("Snap.svg","Snap"),("Gadfly","Gadfly")],AbstractString["fig.select(\"#img-82be9b28-5\")\n   .init_gadfly();"],false,:none)

# %%
violin(singers, :VoicePart, :Height,
       marker=(0.3, :orange, stroke(3)))
# Out:
# Compose.SVG(132.2751322751323mm,79.36507936507938mm,IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=9053, maxsize=Inf, ptr=9054, mark=-1),nothing,"img-fbf9c501",0,Compose.SVGPropertyFrame[],Dict{Type{T},Union{Compose.Property{P<:Compose.PropertyPrimitive},Void}}(),Dict{Compose.ClipPrimitive{P<:NTuple{N,Measures.Measure}},ASCIIString}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}([(6.13333333333334mm,1.0mm),(131.2751322751323mm,1.0mm),(131.2751322751323mm,73.73174603174606mm),(6.13333333333334mm,73.73174603174606mm)])=>"img-fbf9c501-4"),Tuple{Compose.FormPrimitive,ASCIIString}[],Set{AbstractString}(),true,false,nothing,true,"img-fbf9c501-11",false,11,AbstractString["/home/tom/.julia/v0.4/Gadfly/src/gadfly.js"],Tuple{AbstractString,AbstractString}[("Snap.svg","Snap"),("Gadfly","Gadfly")],AbstractString["fig.select(\"#img-fbf9c501-5\")\n   .init_gadfly();"],false,:none)
