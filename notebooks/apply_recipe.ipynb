# %%
using Plots

# this is a custom type that acts just like a Function
immutable MyFunc
   f::Function
end
lambdify(mf::MyFunc) = mf.f


# We add this type as a Plots recipe.  This hook is called after initial Plots
# preprocessing (replacing aliases and other simple steps) but before the core
# data processing.  The return value is a tuple of the new arguments that will
# be passed along.
#
# In this example, a call to `plot(myfunc, a, b, xlim=(-5,5))` is equivalent
# to the call `plot(lambdify(myfunc), a, b, xlim(-5,5))`
function Plots._apply_recipe(d::Plots.KW, mf::MyFunc, args...; kw...)
    (lambdify(mf), args...)
end
# Out:
# _apply_recipe (generic function with 4 methods)

# %%
mf = MyFunc(sin)
plot(mf, 0, 4π)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 36.38625 263.2975
# L 413.95 263.2975
# L 413.95 16.83125
# L 36.38625 16.83125
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p5e403db795)" d="M 36.38625 263.2975
# L 36.38625 16.83125
# " style="fill:none;stroke:#000000;stroke-dasharray:1.000000,3.000000;stroke-dashoffset:0.0;stroke-width:0.5;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0
# L 0 -4
# " id="ma6176f9b41" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="36.38625" xlink:href="#ma6176f9b41" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_3">
#       <defs>
#        <path d="M 0 0
# L 0 4
# " id="m2eadfa2f5f" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="36.38625" xlink:href="#m2eadfa2f5f" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0 -->
#       <defs>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# " id="BitstreamVeraSans-Roman-30"/>
#       </defs>
#       <g transform="translate(33.84125 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_4">
#       <path clip-path="url(#p5e403db795)" d="M 90.323929 263.2975
# L 90.323929 16.83125
# " style="fill:none;stroke:#000000;stroke-dasharray:1.000000,3.000000;stroke-dashoffset:0.0;stroke-width:0.5;"/>
#      </g>
#      <g id="line2d_5">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="90.3239285714" xlink:href="#ma6176f9b41" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="90.3239285714" xlink:href="#m2eadfa2f5f" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 2 -->
#       <defs>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# " id="BitstreamVeraSans-Roman-32"/>
#       </defs>
#       <g transform="translate(87.7789285714 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-32"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_7">
#       <path clip-path="url(#p5e403db795)" d="M 144.261607 263.2975
# L 144.261607 16.83125
# " style="fill:none;stroke:#000000;stroke-dasharray:1.000000,3.000000;stroke-dashoffset:0.0;stroke-width:0.5;"/>
#      </g>
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="144.261607143" xlink:href="#ma6176f9b41" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_9">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="144.261607143" xlink:href="#m2eadfa2f5f" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 4 -->
#       <defs>
#        <path d="M 37.796875 64.3125
# L 12.890625 25.390625
# L 37.796875 25.390625
# z
# M 35.203125 72.90625
# L 47.609375 72.90625
# L 47.609375 25.390625
# L 58.015625 25.390625
# L 58.015625 17.1875
# L 47.609375 17.1875
# L 47.609375 0
# L 37.796875 0
# L 37.796875 17.1875
# L 4.890625 17.1875
# L 4.890625 26.703125
# z
# " id="BitstreamVeraSans-Roman-34"/>
#       </defs>
#       <g transform="translate(141.716607143 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-34"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_10">
#       <path clip-path="url(#p5e403db795)" d="M 198.199286 263.2975
# L 198.199286 16.83125
# " style="fill:none;stroke:#000000;stroke-dasharray:1.000000,3.000000;stroke-dashoffset:0.0;stroke-width:0.5;"/>
#      </g>
#      <g id="line2d_11">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="198.199285714" xlink:href="#ma6176f9b41" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_12">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="198.199285714" xlink:href="#m2eadfa2f5f" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 6 -->
#       <defs>
#        <path d="M 33.015625 40.375
# Q 26.375 40.375 22.484375 35.828125
# Q 18.609375 31.296875 18.609375 23.390625
# Q 18.609375 15.53125 22.484375 10.953125
# Q 26.375 6.390625 33.015625 6.390625
# Q 39.65625 6.390625 43.53125 10.953125
# Q 47.40625 15.53125 47.40625 23.390625
# Q 47.40625 31.296875 43.53125 35.828125
# Q 39.65625 40.375 33.015625 40.375
# M 52.59375 71.296875
# L 52.59375 62.3125
# Q 48.875 64.0625 45.09375 64.984375
# Q 41.3125 65.921875 37.59375 65.921875
# Q 27.828125 65.921875 22.671875 59.328125
# Q 17.53125 52.734375 16.796875 39.40625
# Q 19.671875 43.65625 24.015625 45.921875
# Q 28.375 48.1875 33.59375 48.1875
# Q 44.578125 48.1875 50.953125 41.515625
# Q 57.328125 34.859375 57.328125 23.390625
# Q 57.328125 12.15625 50.6875 5.359375
# Q 44.046875 -1.421875 33.015625 -1.421875
# Q 20.359375 -1.421875 13.671875 8.265625
# Q 6.984375 17.96875 6.984375 36.375
# Q 6.984375 53.65625 15.1875 63.9375
# Q 23.390625 74.21875 37.203125 74.21875
# Q 40.921875 74.21875 44.703125 73.484375
# Q 48.484375 72.75 52.59375 71.296875
# " id="BitstreamVeraSans-Roman-36"/>
#       </defs>
#       <g transform="translate(195.654285714 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-36"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_13">
#       <path clip-path="url(#p5e403db795)" d="M 252.136964 263.2975
# L 252.136964 16.83125
# " style="fill:none;stroke:#000000;stroke-dasharray:1.000000,3.000000;stroke-dashoffset:0.0;stroke-width:0.5;"/>
#      </g>
#      <g id="line2d_14">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="252.136964286" xlink:href="#ma6176f9b41" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_15">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="252.136964286" xlink:href="#m2eadfa2f5f" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 8 -->
#       <defs>
#        <path d="M 31.78125 34.625
# Q 24.75 34.625 20.71875 30.859375
# Q 16.703125 27.09375 16.703125 20.515625
# Q 16.703125 13.921875 20.71875 10.15625
# Q 24.75 6

# %%
# we can add another definition for vectors of our custom type
function Plots._apply_recipe(d::Plots.KW, mf::AbstractArray{MyFunc}, args...; kw...)
    (map(lambdify, mf), args...)
end
# Out:
# _apply_recipe (generic function with 4 methods)

# %%
v = [MyFunc(sin), MyFunc(cos)]
plot(v, 0, 4π)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 36.38625 263.2975
# L 413.95 263.2975
# L 413.95 16.83125
# L 36.38625 16.83125
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pe2b1702434)" d="M 36.38625 263.2975
# L 36.38625 16.83125
# " style="fill:none;stroke:#000000;stroke-dasharray:1.000000,3.000000;stroke-dashoffset:0.0;stroke-width:0.5;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0
# L 0 -4
# " id="m396fe5f5bc" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="36.38625" xlink:href="#m396fe5f5bc" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_3">
#       <defs>
#        <path d="M 0 0
# L 0 4
# " id="m7fb39fdd30" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="36.38625" xlink:href="#m7fb39fdd30" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0 -->
#       <defs>
#        <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# " id="BitstreamVeraSans-Roman-30"/>
#       </defs>
#       <g transform="translate(33.84125 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_4">
#       <path clip-path="url(#pe2b1702434)" d="M 90.323929 263.2975
# L 90.323929 16.83125
# " style="fill:none;stroke:#000000;stroke-dasharray:1.000000,3.000000;stroke-dashoffset:0.0;stroke-width:0.5;"/>
#      </g>
#      <g id="line2d_5">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="90.3239285714" xlink:href="#m396fe5f5bc" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="90.3239285714" xlink:href="#m7fb39fdd30" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 2 -->
#       <defs>
#        <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# " id="BitstreamVeraSans-Roman-32"/>
#       </defs>
#       <g transform="translate(87.7789285714 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-32"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_7">
#       <path clip-path="url(#pe2b1702434)" d="M 144.261607 263.2975
# L 144.261607 16.83125
# " style="fill:none;stroke:#000000;stroke-dasharray:1.000000,3.000000;stroke-dashoffset:0.0;stroke-width:0.5;"/>
#      </g>
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="144.261607143" xlink:href="#m396fe5f5bc" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_9">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="144.261607143" xlink:href="#m7fb39fdd30" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 4 -->
#       <defs>
#        <path d="M 37.796875 64.3125
# L 12.890625 25.390625
# L 37.796875 25.390625
# z
# M 35.203125 72.90625
# L 47.609375 72.90625
# L 47.609375 25.390625
# L 58.015625 25.390625
# L 58.015625 17.1875
# L 47.609375 17.1875
# L 47.609375 0
# L 37.796875 0
# L 37.796875 17.1875
# L 4.890625 17.1875
# L 4.890625 26.703125
# z
# " id="BitstreamVeraSans-Roman-34"/>
#       </defs>
#       <g transform="translate(141.716607143 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-34"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_10">
#       <path clip-path="url(#pe2b1702434)" d="M 198.199286 263.2975
# L 198.199286 16.83125
# " style="fill:none;stroke:#000000;stroke-dasharray:1.000000,3.000000;stroke-dashoffset:0.0;stroke-width:0.5;"/>
#      </g>
#      <g id="line2d_11">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="198.199285714" xlink:href="#m396fe5f5bc" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_12">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="198.199285714" xlink:href="#m7fb39fdd30" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 6 -->
#       <defs>
#        <path d="M 33.015625 40.375
# Q 26.375 40.375 22.484375 35.828125
# Q 18.609375 31.296875 18.609375 23.390625
# Q 18.609375 15.53125 22.484375 10.953125
# Q 26.375 6.390625 33.015625 6.390625
# Q 39.65625 6.390625 43.53125 10.953125
# Q 47.40625 15.53125 47.40625 23.390625
# Q 47.40625 31.296875 43.53125 35.828125
# Q 39.65625 40.375 33.015625 40.375
# M 52.59375 71.296875
# L 52.59375 62.3125
# Q 48.875 64.0625 45.09375 64.984375
# Q 41.3125 65.921875 37.59375 65.921875
# Q 27.828125 65.921875 22.671875 59.328125
# Q 17.53125 52.734375 16.796875 39.40625
# Q 19.671875 43.65625 24.015625 45.921875
# Q 28.375 48.1875 33.59375 48.1875
# Q 44.578125 48.1875 50.953125 41.515625
# Q 57.328125 34.859375 57.328125 23.390625
# Q 57.328125 12.15625 50.6875 5.359375
# Q 44.046875 -1.421875 33.015625 -1.421875
# Q 20.359375 -1.421875 13.671875 8.265625
# Q 6.984375 17.96875 6.984375 36.375
# Q 6.984375 53.65625 15.1875 63.9375
# Q 23.390625 74.21875 37.203125 74.21875
# Q 40.921875 74.21875 44.703125 73.484375
# Q 48.484375 72.75 52.59375 71.296875
# " id="BitstreamVeraSans-Roman-36"/>
#       </defs>
#       <g transform="translate(195.654285714 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-36"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_13">
#       <path clip-path="url(#pe2b1702434)" d="M 252.136964 263.2975
# L 252.136964 16.83125
# " style="fill:none;stroke:#000000;stroke-dasharray:1.000000,3.000000;stroke-dashoffset:0.0;stroke-width:0.5;"/>
#      </g>
#      <g id="line2d_14">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="252.136964286" xlink:href="#m396fe5f5bc" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_15">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="252.136964286" xlink:href="#m7fb39fdd30" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 8 -->
#       <defs>
#        <path d="M 31.78125 34.625
# Q 24.75 34.625 20.71875 30.859375
# Q 16.703125 27.09375 16.703125 20.515625
# Q 16.703125 13.921875 20.71875 10.15625
# Q 24.75 6
