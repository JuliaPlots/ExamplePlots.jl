# %%
using Plots
pyplot()

n = 100
x1, x2 = rand(n), 3rand(n)

# see issue #186... this is the standard histogram call
# our goal is to use the same edges for both series
histogram(Any[x1, x2], line=(3,0.2,:green), fillcolor=[:red :black], fillalpha=0.2)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 22.05 263.2975
# L 412.67875 263.2975
# L 412.67875 16.83125
# L 22.05 16.83125
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pb25ff9fb65)" d="M 22.05 263.2975
# L 22.05 16.83125
# ...

# %%
# vcat the data, then call Base.hist to get edges
edges,_ = hist(vcat(x1, x2), 50)
# Out:
# (0.0:0.2:10.0,[21,21,18,31,19,0,3,1,3,1  …  4,2,6,0,3,1,3,1,2,2])

# %%
# create the x/y coords of the histogram outline
function histline(data, edges)
    cnts = hist(data, edges)[2]
    x, y = zeros(0), zeros(0)
    for i=1:length(c)
        append!(x, Float64[edges[i], edges[i], edges[i+1], edges[i+1]])
        append!(y, Float64[0, cnts[i], cnts[i], 0])
    end
    x, y
end
# Out:
# histline (generic function with 1 method)

# %%
# plot the histograms as lines (fill to 0, etc)
plot(histline(x1, edges)...)
plot!(histline(x2, edges)..., fill=0)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 27.14 263.2975
# L 413.95 263.2975
# L 413.95 16.83125
# L 27.14 16.83125
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p1b7bb9998d)" d="M 27.14 263.2975
# L 27.14 16.83125
# ...
