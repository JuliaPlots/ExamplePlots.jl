# %%
using Plots
pyplot(reuse=true, size=(400,300))
srand(1)
n = 100
y = randn(n)
w = weights = Float64[x>0 ? 10 : 1 for x in y]
x = linspace(0,4π,10)
zf(x,y) = x+y+sin(x)+cos(y);

# %%
mat = Float64[i>=j ? 0 : 1 for i=1:10,j=1:5]
spy(mat)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 99.415625 191.2975
# L 188.584375 191.2975
# L 188.584375 12.96
# L 99.415625 12.96
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pbcfeb6f98a)" d="M 108.3325 191.2975
# L 108.3325 12.96
# ...

# %%
contour3d(x, x, zf, fa=0.4, levels=10)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="patch_2">
#    <path d="M 12.96 197.233125
# L 222.624 197.233125
# L 222.624 12.96
# L 12.96 12.96
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="pane3d_1">
#    <g id="patch_3">
#     <path d="M 40.754203 156.515259
# L 100.761137 111.335664
# L 99.762085 25.004873
# L 36.409371 65.59781
# ...

# %%
n, m = 15, 4
xs = [string("x",i) for i=1:n]
ys = [string("y",i) for i=1:m]
z = rand(["A","B","C"], n, m)
@show z'
heatmap(xs, ys, z, yflip=true, c=[:red,:blue,:green], l=(1,:black),
grid=false, axiscolor=nothing, border=nothing, size=(600,300), aspect_ratio=:equal)
# Out:
# z' = ASCIIString["C" "A" "A" "C" "C" "A" "A" "B" "A" "A" "C" "A" "C" "C" "A"
#             "B" "B" "A" "C" "B" "C" "A" "B" "A" "C" "B" "B" "C" "B" "C"
#             "B" "A" "A" "A" "B" "B" "B" "B" "C" "A" "A" "C" "C" "B" "A"
#             "B" "C" "B" "A" "C" "B" "C" "C" "C" "A" "C" "B" "C" "C" "B"]
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 432 216" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 432 216
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
# ...

# %%
n = 1000
x, y = 10rand(n),10rand(n)
z = Float64[sin(x[i])+cos(y[i]) for i=1:n]
surface(x,y,z, size=(500,300))
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 360 216" width="360pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 360 216
# L 360 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="patch_2">
#    <path d="M 12.96 203.04
# L 280.224 203.04
# L 280.224 12.96
# L 12.96 12.96
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="pane3d_1">
#    <g id="patch_3">
#     <path d="M 48.389973 161.039019
# L 124.882328 114.43571
# L 123.608812 25.384435
# L 42.851507 67.25655
# ...

# %%
Θ = linspace(0,1.5π,100)
r = abs(0.1randn(100)+sin(3Θ))
plot(Θ, r, polar=true, m=2)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 144 189.66475
# C 165.657745 189.66475 186.43136 181.060037 201.745699 165.745699
# C 217.060037 150.43136 225.66475 129.657745 225.66475 108
# C 225.66475 86.342255 217.060037 65.56864 201.745699 50.254301
# C 186.43136 34.939963 165.657745 26.33525 144 26.33525
# ...

# %%
y = rand(100)
plot(0:10:100,rand(11,4),lab="lines",w=3,palette=:grays,fill=(0,:auto), α=0.6)
scatter!(y,zcolor=abs(y - 0.5),m=(:heat,0.8,stroke(1,:green)),ms=10 * abs(y - 0.5) + 4,lab="grad")
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 36.38625 191.2975
# L 227.30925 191.2975
# L 227.30925 16.83125
# L 36.38625 16.83125
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pe58df95c4c)" d="M 36.38625 191.2975
# L 36.38625 16.83125
# ...

# %%
x=randn(10000); histogram2d(x, randn(10000), nbins=20, norm=true, weights=float(x.<0))
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 28.75375 191.2975
# L 222.298956 191.2975
# L 222.298956 12.96
# L 28.75375 12.96
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p5cb2aea345)" d="M 43.621273 191.2975
# L 43.621273 12.96
# ...

# %%
ys = Vector[rand(10), rand(20)]
plot(ys, color=[:black :orange], line=(:dot,4), marker=([:hex :d],12,0.8,stroke(3,:gray)))
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 36.38625 191.2975
# L 269.95 191.2975
# L 269.95 16.83125
# L 36.38625 16.83125
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p933f2fb78a)" d="M 36.38625 191.2975
# L 36.38625 16.83125
# ...

# %%
using RDatasets
singers = dataset("lattice", "singer")
boxplot(singers, :VoicePart, :Height, marker = (0.3, :orange, stroke(2,:black)),leg=false)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 27.14 191.2975
# L 275.04 191.2975
# L 275.04 16.83125
# L 27.14 16.83125
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pf6f40c4343)" d="M 54.684444 191.2975
# L 54.684444 16.83125
# ...

# %%
using Plots
pyplot(reuse=true, size=(400,300))
srand(1)
n = 100
y = randn(n)
w = weights = Float64[x>0 ? 10 : 1 for x in y]
x = linspace(0,4π,10)
zf(x,y) = x+y+sin(x)+cos(y);

# %%
heatmap(x,x,zf,xlim=(0,4π),ylim=(0,4π), border=nothing)
# Out:
# [Plots.jl] Initializing backend: pyplot
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 27.14 191.2975
# L 225.46 191.2975
# L 225.46 12.96
# L 27.14 12.96
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p90e642bf6b)" d="M 27.14 191.2975
# ...

# %%
contour(x, x, zf, fa=0.4, levels=50)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 27.14 191.2975
# L 225.46 191.2975
# L 225.46 12.96
# L 27.14 12.96
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pfe20994a45)" d="M 27.14 191.2975
# L 27.14 12.96
# ...

# %%
surface(x, x, zf)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="patch_2">
#    <path d="M 12.96 199.931139
# L 220.6322 199.931139
# L 220.6322 12.96
# L 12.96 12.96
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="pane3d_1">
#    <g id="patch_3">
#     <path d="M 40.490159 158.617107
# L 99.927029 112.77602
# L 98.937469 25.181227
# L 36.186603 66.3685
# ...

# %%
wireframe(x,x,zf,contours=true)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="patch_2">
#    <path d="M 12.96 197.233125
# L 222.624 197.233125
# L 222.624 18.766875
# L 12.96 18.766875
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="pane3d_1">
#    <g id="patch_3">
#     <path d="M 40.754203 157.798373
# L 100.761137 114.042493
# L 99.762085 30.432186
# L 36.409371 69.745945
# ...

# %%
plot(y, xlab="X", ylab="Y", title="My Title")
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 44.399688 175.651563
# L 267.405 175.651563
# L 267.405 26.318281
# L 44.399688 26.318281
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p3a7b6e7f40)" d="M 44.399688 175.651563
# ...

# %%
add_theme(:ggplotgreen, base=:ggplot2, bginside=:green)
set_theme(:ggplotgreen)

# %%
plot(y, xlab="X", ylab="Y", title="My Title")
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 44.399688 175.651563
# L 267.405 175.651563
# L 267.405 26.318281
# L 44.399688 26.318281
# z
# " style="fill:#008000;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p4df50a9065)" d="M 44.399688 175.651563
# ...

# %%
set_theme(:ggplot2)

# %%
scatter(y)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 28.75375 191.2975
# L 267.405 191.2975
# L 267.405 16.83125
# L 28.75375 16.83125
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pe435af7929)" d="M 28.75375 191.2975
# L 28.75375 16.83125
# ...

# %%
scatter(y, zcolor=y, α=0.3)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 28.75375 191.2975
# L 220.88065 191.2975
# L 220.88065 16.83125
# L 28.75375 16.83125
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p3e98c0ed5b)" d="M 28.75375 191.2975
# L 28.75375 16.83125
# ...

# %%
plot(y, zcolor=y, m=(10,:inferno), α=0.3)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 28.75375 191.2975
# L 221.111719 191.2975
# L 221.111719 16.83125
# L 28.75375 16.83125
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pa50388629c)" d="M 28.75375 191.2975
# ...

# %%
append!(current(), 1,rand(50))
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 28.75375 191.2975
# L 221.112499 191.2975
# L 221.112499 12.96
# L 28.75375 12.96
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p9b8ec61917)" d="M 53.282718 191.2975
# L 53.282718 12.96
# ...

# %%
plot3d(1:100, sin(1:100), y, α=0.5, m=(10), l=(2,0.2))
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="patch_2">
#    <path d="M 12.96 203.04
# L 275.04 203.04
# L 275.04 12.96
# L 12.96 12.96
# z
# " style="fill:#d3d3d3;"/>
#   </g>
#   <g id="pane3d_1">
#    <g id="patch_3">
#     <path d="M 47.702754 161.039019
# L 122.711421 114.43571
# L 121.462606 25.384435
# L 42.271714 67.25655
# ...

# %%
plot3d(1:100, sin(1:100), y, m=(10,0.4,:inferno), l=(2,0.2), zcolor=y)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="patch_2">
#    <path d="M 12.96 203.04
# L 219.9589 203.04
# L 219.9589 12.96
# L 12.96 12.96
# z
# " style="fill:#d3d3d3;"/>
#   </g>
#   <g id="pane3d_1">
#    <g id="patch_3">
#     <path d="M 40.400903 161.039019
# L 99.645071 114.43571
# L 98.658718 25.384435
# L 36.1113 67.25655
# ...

# %%
histogram(y, l=(3,0.5,:red), c=:green)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 27.14 191.2975
# L 272.495 191.2975
# L 272.495 16.83125
# L 27.14 16.83125
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pad44fa1e9e)" d="M 27.14 191.2975
# L 27.14 16.83125
# ...

# %%
histogram(y, c=:green, orientation=:h)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 28.75375 191.2975
# L 269.95 191.2975
# L 269.95 16.83125
# L 28.75375 16.83125
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p0eafebaa29)" d="M 28.75375 191.2975
# L 28.75375 16.83125
# ...

# %%
histogram(y, l=(3,0.5,:red), c=:green, orientation=:h,
            normed=true, weights=w)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 28.75375 191.2975
# L 268.67875 191.2975
# L 268.67875 16.83125
# L 28.75375 16.83125
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p59b468b27a)" d="M 28.75375 191.2975
# L 28.75375 16.83125
# ...

# %%
bar(y[1:10], l=(3,0.5), c=:green)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 28.75375 191.2975
# L 269.95 191.2975
# L 269.95 16.83125
# L 28.75375 16.83125
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p2f153c2e4a)" d="M 28.75375 191.2975
# L 28.75375 16.83125
# ...

# %%
bar(y[1:10], l=(3,0.5,:red), c=:green, m=(:x,20,:black), orientation=:h)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 27.14 191.2975
# L 272.495 191.2975
# L 272.495 16.83125
# L 27.14 16.83125
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p3851bfba46)" d="M 27.14 191.2975
# L 27.14 16.83125
# ...

# %%
sticks(sort(rand(10)), y[1:10], l=(3,0.5), c=:green, m=(10,0.3), orientation=:h)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 29.6825 191.2975
# L 272.495 191.2975
# L 272.495 16.83125
# L 29.6825 16.83125
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pc6703d96b0)" d="M 29.6825 191.2975
# L 29.6825 16.83125
# ...

# %%
histogram2d(y, randn(n), nbin=5, norm=true)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 28.75375 191.2975
# L 223.31395 191.2975
# L 223.31395 16.544003
# L 28.75375 16.544003
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p1eb0eacfb1)" d="M 40.144015 191.2975
# ...

# %%
hexbin(y, randn(n), nbin=5, w=2)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 28.75375 191.2975
# L 225.78275 191.2975
# L 225.78275 12.96
# L 28.75375 12.96
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p4621c41ed6)" d="M 40.288548 191.2975
# L 40.288548 12.96
# ...

# %%
plot(y, title="my title", tickfont=font("Times",5),
legendfont=font("Arial",18), guidefont=font("Symbol",30))
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 24.331094 194.200938
# L 270.268125 194.200938
# L 270.268125 40.755313
# L 24.331094 40.755313
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p10aeb9ebf1)" d="M 24.331094 194.200938
# ...

# %%
subplot(plot(randn(3)),
    plot(randn(3)),
    plot(randn(3)),
    layout=[1, 1, 1]
)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 41.47625 55.9375
# L 268.67875 55.9375
# L 268.67875 16.83125
# L 41.47625 16.83125
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="line2d_1">
#     <path clip-path="url(#p13e79ddce2)" d="M 41.47625 40.944695
# L 155.0775 18.78219
# L 268.67875 51.652147
# ...

# %%
hline(rand(4), style=:dash)
vline!(rand(3), c=:red)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 29.6825 191.2975
# L 268.67875 191.2975
# L 268.67875 16.83125
# L 29.6825 16.83125
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pb6a4e1c080)" d="M 29.6825 191.2975
# L 29.6825 16.83125
# ...

# %%
x = linspace(0,3,20)
y = linspace(0,10,20)
z = Float64[5xi+yi for xi=x,yi=y]
heatmap(x, y, z)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 28.75375 191.2975
# L 222.84955 191.2975
# L 222.84955 18.766875
# L 28.75375 18.766875
# z
# " style="fill:#d3d3d3;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p58e4a6a592)" d="M 28.75375 191.2975
# ...

# %%
png("/tmp/tmp")

# %%
using Plots
x = y = linspace(-5,5,30)
z = sin(sqrt(Float64[xi^2+yi^2 for xi=x, yi=y]));
surface(x,y,z,α=0.7)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="patch_2">
#    <path d="M 12.96 203.04
# L 218.416756 203.04
# L 218.416756 12.96
# L 12.96 12.96
# z
# " style="fill:#d3d3d3;"/>
#   </g>
#   <g id="pane3d_1">
#    <g id="patch_3">
#     <path d="M 40.196468 161.039019
# L 98.999266 114.43571
# L 98.020262 25.384435
# L 35.938822 67.25655
# ...

# %%
Gx, Gy = Plots.pynp.pymember(:gradient)(z)
G = Gx.^2 + Gy.^2
surface(x, y, z, α=0.8, zcolor=wrap(G))
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="216pt" version="1.1" viewBox="0 0 288 216" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 216
# L 288 216
# L 288 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="patch_2">
#    <path d="M 12.96 203.04
# L 275.04 203.04
# L 275.04 12.96
# L 12.96 12.96
# z
# " style="fill:#d3d3d3;"/>
#   </g>
#   <g id="pane3d_1">
#    <g id="patch_3">
#     <path d="M 47.702754 161.039019
# L 122.711421 114.43571
# L 121.462606 25.384435
# L 42.271714 67.25655
# ...
